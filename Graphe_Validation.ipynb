# %% [markdown]
# # **Import Data**

# %%
import pandas as pd
import re

# === 2️⃣ Chargement du dataset ===
file_path = "cybersecurity_dataset.csv"
df = pd.read_csv(file_path, encoding='utf-8', low_memory=False)

print("✅ Dataset chargé avec succès !")
print("Dimensions initiales :", df.shape)
print("Colonnes :", df.columns.tolist())
# Out:
# ✅ Dataset chargé avec succès !
# Dimensions initiales : (2411, 3)
# Colonnes : ['system', 'user', 'assistant']

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **Import libreries**

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 38.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)

# %%
import nltk
import numpy as np
import pandas as pd
import spacy
import matplotlib.pyplot as plt
import seaborn as sns


from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec

# %% [markdown]
# **Hundle null value**

# %%
# 🧩 3️⃣ Vérification et suppression des valeurs manquantes / doublons
# ============================================================

# Vérifier les valeurs manquantes
print("\n🔍 Valeurs manquantes :")
print(df.isnull().sum())

# Supprimer les lignes où les textes importants sont vides
df.dropna(subset=['user', 'assistant'], inplace=True)

# Supprimer les doublons exacts sur les 3 colonnes
df.drop_duplicates(subset=['system', 'user', 'assistant'], inplace=True)

print("\n✅ Doublons supprimés. Nouvelle taille :", df.shape)
# Out:
# 🔍 Valeurs manquantes :
# system       1
# user         1
# assistant    2
# dtype: int64
#
# ✅ Doublons supprimés. Nouvelle taille : (2409, 3)

# %% [markdown]
# **Cleaning Text**

# %%
# ✨ 4️⃣ Nettoyage du texte (ponctuation, chiffres, HTML, espaces)
# ============================================================

def clean_text(text):
    """Nettoie le texte brut : suppression HTML, ponctuation, normalisation."""
    if pd.isnull(text):
        return ""
    text = re.sub(r'<[^>]+>', ' ', text)              # supprimer balises HTML
    text = re.sub(r'[^a-zA-Z0-9\s:/.\-]', ' ', text)  # retirer caractères spéciaux
    text = re.sub(r'\s+', ' ', text)                  # réduire les espaces
    text = text.lower().strip()                       # minuscule et trim
    return text
  # Nettoyage des colonnes textuelles
df['system_clean'] = df['system'].apply(clean_text)
df['user_clean'] = df['user'].apply(clean_text)
df['assistant_clean'] = df['assistant'].apply(clean_text)

# %%
# ============================================================
# 🧮 6️⃣ Filtrage supplémentaire (textes courts, doublons)
# ============================================================

# Supprimer les lignes avec texte trop court (non informatif)
df = df[df['assistant_clean'].str.len() > 10]

# Supprimer les doublons sur le texte nettoyé
df.drop_duplicates(subset=['assistant_clean'], inplace=True)

print("\n📊 Taille finale du dataset :", df.shape)
# Out:
# 📊 Taille finale du dataset : (2408, 6)

# %% [markdown]
# **Download resources**

# %%
# 🧠 Étape NLP - Prétraitement du texte (adapté cybersécurité)
# ============================================================

# === 1️⃣ Importation des bibliothèques nécessaires ===

# Télécharger les ressources nécessaires (à exécuter une seule fois)
nltk.download('punkt')
nltk.download('punkt_tab')  # ✅ Ajout nécessaire pour les nouvelles versions de NLTK
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# **Edit StopWords**

# %%
# === 2️⃣ Création d'une liste de stopwords personnalisée ===

# Liste standard de mots vides en anglais
stop_words = set(stopwords.words('english'))

# Liste des termes techniques à CONSERVER (propres à la cybersécurité)
tech_words = [
   'no', 'not', 'nor', 'never', 'none', 'without', "n't",
  'attack', 'attacks', 'malware', 'virus', 'phishing', 'breach',
'exploit', 'vulnerability', 'vulnerabilities', 'threat',
'incident', 'security', 'risk', 'encryption', 'firewall',
'authentication', 'password', 'network', 'data', 'system',
'software', 'hardware', 'server', 'client', 'ransomware',
'sql', 'xss', 'dos', 'ddos', 'access', 'privilege',
'cve', 'mitre', 'nist', 'vuln', 'defense', 'attackers',
'intrusion', 'http', 'https', 'ip', 'get', 'post', 'url',
'csrf', 'ftp', 'dns', 'ssh', 'tcp', 'udp', 'trojan', 'worm',
'cookie', 'request', 'response', 'header', 'token', 'session',
'router'
]

# Extra filler words to remove
extra_fillers = {
    'example', 'etc', 'many', 'various', 'several', 'certain',
    'thing', 'things', 'something', 'anything'
}
custom_stopwords = stop_words.difference(tech_words).union(extra_fillers)


print("✅ Stopwords adaptés à la cybersécurité chargés :", len(stop_words))
print("✅ Stopwords adaptés à la cybersécurité chargés :", len(custom_stopwords))
# Out:
# ✅ Stopwords adaptés à la cybersécurité chargés : 198
# ✅ Stopwords adaptés à la cybersécurité chargés : 205

# %% [markdown]
# **Prepating NLP**

# %%
# === 3️⃣ Préparation des outils NLP ===
lemmatizer = WordNetLemmatizer()

# Fonction principale de prétraitement
def preprocess_text(text):
    """
    Effectue :
      - Tokenisation
      - Suppression des stopwords
      - Lemmatisation
    """
    # 1. Tokenisation
    tokens = word_tokenize(text)

    # 2. Filtrer : on garde uniquement les mots alphabétiques non-stopwords
    tokens = [w for w in tokens if w.isalpha() and w not in custom_stopwords]

    # 3. Lemmatisation (retour à la racine des mots)
    tokens = [lemmatizer.lemmatize(w) for w in tokens]

    # 4. Reconstruction du texte final
    return " ".join(tokens)

# %% [markdown]
# Applicate NLP on assitant_clean

# %%
# === 4️⃣ Application du traitement NLP sur la colonne 'assistant_clean' ===
df['assistant_nlp'] = df['assistant_clean'].apply(preprocess_text)

# %%
# === 5️⃣ Vérification du résultat sur quelques exemples ===
print("\n🔍 Exemple de transformation avant / après :\n")
for i in range(3):
    print("🧾 Texte original :", df['assistant_clean'].iloc[i][:150], "...")
    print("🔹 Texte NLP :", df['assistant_nlp'].iloc[i][:150], "\n")
# Out:
# 🔍 Exemple de transformation avant / après :
#
# 🧾 Texte original : reflected xss attacks occur when an attacker sends a request containing a malicious script to a vulnerable application that is then returned by the se ...
# 🔹 Texte NLP : reflected xss attack occur attacker sends request containing malicious script vulnerable application returned server rendered victim browser without p
#
# 🧾 Texte original : the difference between reflected cross-site scripting xss vulnerabilities in a web page versus those in an api endpoint with a content type of applica ...
# 🔹 Texte NLP : difference reflected scripting xss vulnerability web page versus api endpoint content type primarily due browser interpret render returned data standa
#
# 🧾 Texte original : dom clobbering occurs when an object property name in the document object model dom is overwritten by a malicious property allowing the attacker to by ...
# 🔹 Texte NLP : dom clobbering occurs object property name document object model dom overwritten malicious property allowing attacker bypass security check execute ar

# %% [markdown]
# **English model setup**

# %%
# Charger le modèle anglais
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# **Linguistic Analysis**

# %%
# --- POS Tagging ---
def extract_pos(text):
    doc = nlp(text)
    return [(token.text, token.pos_) for token in doc]


def extract_ner(text):
    doc = nlp(text)
    # doc.ents contient uniquement les entités reconnues
    return [(ent.text, ent.label_) for ent in doc.ents]

# %% [markdown]
# **Display POS Tagging and Named Entity Recognition for the First 5 Texts**

# %%
# Exemple : on prend les 5 premières lignes pour afficher
for i, text in enumerate(df['assistant_clean'].head(5)):
    print(f"\n🔹 Texte original {i+1} :\n{text}\n")

    # POS tagging
    pos_tags = extract_pos(text)
    print("POS Tags :")
    print(pos_tags)

    # NER
    named_entities = extract_ner(text)
    print("Named Entities :")
    print(named_entities)
# Out:
# 🔹 Texte original 1 :
# reflected xss attacks occur when an attacker sends a request containing a malicious script to a vulnerable application that is then returned by the server and rendered on the victim s browser without proper sanitization. the attack begins with the attacker crafting a url that includes their payload often embedded within query parameters or other user input fields. this crafted url is distributed via email social media or other means to trick users into clicking it. when the victim clicks the link the request is sent to the web server hosting the vulnerable application. the server processes the request but does not adequately filter out malicious content in the inputs. consequently when generating a response such as an error message search results page or dynamic page content the server includes the attacker s payload in the html output. the victim s browser interprets and executes the injected script when rendering the page enabling the attacker to steal session cookies capture keystrokes redirect users to malicious sites or perform other unauthorized actions. the key vulnerability here is that user input is blindly trusted and reflected back without appropriate validation or escaping. in a reflected xss scenario there is no persistent storage of the malicious script on the server it exists only temporarily in the server s response to the specific request from the victim. thus each time an attacker wants to exploit the vulnerability they must send a new crafted url and entice another user to click it. the most common vector for distributing these urls is via email or social engineering techniques. reflected xss attacks are often referred to as non-persistent because the malicious script does not remain on the server beyond a single request/response cycle. it is critical that web applications implement strict input validation output encoding and content security policies csp to prevent reflected xss vulnerabilities from being exploited. by validating user inputs for syntax and context before inclusion in html outputs developers can ensure that no dangerous scripts are executed by browsers when the page loads. additionally employing http headers such as x-content-type-options and strict-transport-security further enhances security by preventing mime type sniffing attacks and ensuring encrypted connections respectively. the combination of these measures significantly reduces the risk of successful reflected xss exploits in modern web applications. reflected xss attacks are often considered to be one of the most common types of cross-site scripting vulnerabilities found on the internet today due largely to their reliance on human interaction rather than exploiting flaws within software code itself.
#
# POS Tags :
# [('reflected', 'VERB'), ('xss', 'PROPN'), ('attacks', 'NOUN'), ('occur', 'VERB'), ('when', 'SCONJ'), ('an', 'DET'), ('attacker', 'NOUN'), ('sends', 'VERB'), ('a', 'DET'), ('request', 'NOUN'), ('containing', 'VERB'), ('a', 'DET'), ('malicious', 'ADJ'), ('script', 'NOUN'), ('to', 'ADP'), ('a', 'DET'), ('vulnerable', 'ADJ'), ('application', 'NOUN'), ('that', 'PRON'), ('is', 'AUX'), ('then', 'ADV'), ('returned', 'VERB'), ('by', 'ADP'), ('the', 'DET'), ('server', 'NOUN'), ('and', 'CCONJ'), ('rendered', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('victim', 'NOUN'), ('s', 'PART'), ('browser', 'NOUN'), ('without', 'ADP'), ('proper', 'ADJ'), ('sanitization', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('attack', 'NOUN'), ('begins', 'VERB'), ('with', 'ADP'), ('the', 'DET'), ('attacker', 'NOUN'), ('crafting', 'VERB'), ('a', 'DET'), ('url', 'NOUN'), ('that', 'PRON'), ('includes', 'VERB'), ('their', 'PRON'), ('payload', 'NOUN'), ('often', 'ADV'), ('embedded', 'VERB'), ('within', 'ADP'), ('query', 'NOUN'), ('parameters', 'NOUN'), ('or', 'CCONJ'), ('other', 'ADJ'), ('user', 'NOUN'), ('input', 'NOUN'), ('fields', 'NOUN'), ('.', 'PUNCT'), ('this', 'DET'), ('crafted', 'VERB'), ('url', 'NOUN'), ('is', 'AUX'), ('distributed', 'VERB'), ('via', 'ADP'), ('email', 'NOUN'), ('social', 'ADJ'), ('media', 'NOUN'), ('or', 'CCONJ'), ('other', 'ADJ'), ('means', 'NOUN'), ('to', 'PART'), ('trick', 'VERB'), ('users', 'NOUN'), ('into', 'ADP'), ('clicking', 'VERB'), ('it', 'PRON'), ('.', 'PUNCT'), ('when', 'SCONJ'), ('the', 'DET'), ('victim', 'NOUN'), ('clicks', 'VERB'), ('the', 'DET'), ('link', 'NOUN'), ('the', 'DET'), ('request', 'NOUN'), ('is', 'AUX'), ('sent', 'VERB'), ('to', 'ADP'), ('the', 'DET'), ('web', 'NOUN'), ('server', 'NOUN'), ('hosting', 'VERB'), ('the', 'DET'), ('vulnerable', 'ADJ'), ('application', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('server', 'NOUN'), ('processes', 'VERB'), ('the', 'DET'), ('request', 'NOUN'), ('but', 'CCONJ'), ('does', 'AUX'), ('not', 'PART'), ('adequately', 'ADV'), ('filter', 'VERB'), ('out', 'ADP'), ('malicious', 'ADJ'), ('content', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('inputs', 'NOUN'), ('.', 'PUNCT'), ('consequently', 'ADV'), ('when', 'SCONJ'), ('generating', 'VERB'), ('a', 'DET'), ('response', 'NOUN'), ('such', 'ADJ'), ('as', 'ADP'), ('an', 'DET'), ('error', 'NOUN'), ('message', 'NOUN'), ('search', 'NOUN'), ('results', 'NOUN'), ('page', 'NOUN'), ('or', 'CCONJ'), ('dynamic', 'ADJ'), ('page', 'NOUN'), ('content', 'NOUN'), ('the', 'DET'), ('server', 'NOUN'), ('includes', 'VERB'), ('the', 'DET'), ('attacker', 'NOUN'), ('s', 'PART'), ('payload', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('html', 'PROPN'), ('output', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('victim', 'NOUN'), ('s', 'PART'), ('browser', 'NOUN'), ('interprets', 'VERB'), ('and', 'CCONJ'), ('executes', 'VERB'), ('the', 'DET'), ('injected', 'VERB'), ('script', 'NOUN'), ('when', 'SCONJ'), ('rendering', 'VERB'), ('the', 'DET'), ('page', 'NOUN'), ('enabling', 'VERB'), ('the', 'DET'), ('attacker', 'NOUN'), ('to', 'PART'), ('steal', 'VERB'), ('session', 'NOUN'), ('cookies', 'NOUN'), ('capture', 'VERB'), ('keystrokes', 'NOUN'), ('redirect', 'VERB'), ('users', 'NOUN'), ('to', 'ADP'), ('malicious', 'ADJ'), ('sites', 'NOUN'), ('or', 'CCONJ'), ('perform', 'VERB'), ('other', 'ADJ'), ('unauthorized', 'ADJ'), ('actions', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('key', 'ADJ'), ('vulnerability', 'NOUN'), ('here', 'ADV'), ('is', 'AUX'), ('that', 'SCONJ'), ('user', 'NOUN'), ('input', 'NOUN'), ('is', 'AUX'), ('blindly', 'ADV'), ('trusted', 'VERB'), ('and', 'CCONJ'), ('reflected', 'VERB'), ('back', 'ADV'), ('without', 'ADP'), ('appropriate', 'ADJ'), ('validation', 'NOUN'), ('or', 'CCONJ'), ('escaping', 'VERB'), ('.', 'PUNCT'), ('in', 'ADP'), ('a', 'DET'), ('reflected', 'VERB'), ('xss', 'PROPN'), ('scenario', 'PROPN'), ('there', 'PRON'), ('is', 'VERB'), ('no', 'DET'), ('persistent', 'ADJ'), ('storage', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('malicious', 'ADJ'), ('script', 'NOUN'), ...
# Named Entities :
# [('today', 'DATE')]
#
# 🔹 Texte original 2 :
# the difference between reflected cross-site scripting xss vulnerabilities in a web page versus those in an api endpoint with a content type of application/json is primarily due to how browsers interpret and render the returned data. in standard html pages any user-provided input that ends up within the document body can be interpreted as html if not properly sanitized. however json responses are inherently structured text browsers do not automatically execute javascript code contained in json objects unless it is explicitly injected into a context where the browser interprets it as executable script e.g. through eval document.write or innerhtml . thus a reflected xss vulnerability on an api endpoint requires that the data from the api be incorporated into a page in such a way that user-provided input becomes part of the executed javascript code. for instance if the api s json response is used to dynamically construct dom elements without proper sanitization like embedding it directly with document.write or using eval on the response then an attacker can inject malicious script that executes when the page loads. a potential attack scenario involves a search feature where the user input is reflected in the url and then passed to an api endpoint which returns the data as json. if the javascript code in the web application then uses this data unsafely e.g. via eval or innerhtml it can execute any script provided by the attacker leading to a successful xss attack. the key difference is that for the vulnerability to be exploitable on an api endpoint the client-side code must misinterpret json as executable script rather than just data. proper coding practices such as not using eval and carefully sanitizing inputs used in dom manipulation can mitigate these risks. also if the api returns a content type of application/json with proper headers like content-type: application/json charset utf-8 many browsers will treat it as plain text rather than executable code reducing the attack surface. however if the client-side javascript mishandles json parsing and injection into dom elements the vulnerability can still be exploited. proper input validation on both server and client sides combined with safe coding practices for dynamically generated content remains crucial to prevent such vulnerabilities. additionally employing content security policy csp can block dangerous scripts from executing even if they are injected into the page.
#
# POS Tags :
# [('the', 'DET'), ('difference', 'NOUN'), ('between', 'ADP'), ('reflected', 'VERB'), ('cross', 'ADJ'), ('-', 'ADJ'), ('site', 'ADJ'), ('scripting', 'NOUN'), ('xss', 'PROPN'), ('vulnerabilities', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('web', 'NOUN'), ('page', 'NOUN'), ('versus', 'ADP'), ('those', 'PRON'), ('in', 'ADP'), ('an', 'DET'), ('api', 'NOUN'), ('endpoint', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('content', 'NOUN'), ('type', 'NOUN'), ('of', 'ADP'), ('application', 'NOUN'), ('/', 'SYM'), ('json', 'NOUN'), ('is', 'AUX'), ('primarily', 'ADV'), ('due', 'ADJ'), ('to', 'ADP'), ('how', 'SCONJ'), ('browsers', 'NOUN'), ('interpret', 'VERB'), ('and', 'CCONJ'), ('render', 'VERB'), ('the', 'DET'), ('returned', 'VERB'), ('data', 'NOUN'), ('.', 'PUNCT'), ('in', 'ADP'), ('standard', 'ADJ'), ('html', 'PROPN'), ('pages', 'NOUN'), ('any', 'DET'), ('user', 'NOUN'), ('-', 'PUNCT'), ('provided', 'VERB'), ('input', 'NOUN'), ('that', 'PRON'), ('ends', 'VERB'), ('up', 'ADP'), ('within', 'ADP'), ('the', 'DET'), ('document', 'NOUN'), ('body', 'NOUN'), ('can', 'AUX'), ('be', 'AUX'), ('interpreted', 'VERB'), ('as', 'ADP'), ('html', 'PROPN'), ('if', 'SCONJ'), ('not', 'PART'), ('properly', 'ADV'), ('sanitized', 'VERB'), ('.', 'PUNCT'), ('however', 'ADV'), ('json', 'PROPN'), ('responses', 'NOUN'), ('are', 'AUX'), ('inherently', 'ADV'), ('structured', 'VERB'), ('text', 'NOUN'), ('browsers', 'NOUN'), ('do', 'AUX'), ('not', 'PART'), ('automatically', 'ADV'), ('execute', 'VERB'), ('javascript', 'PROPN'), ('code', 'NOUN'), ('contained', 'VERB'), ('in', 'ADP'), ('json', 'NOUN'), ('objects', 'NOUN'), ('unless', 'SCONJ'), ('it', 'PRON'), ('is', 'AUX'), ('explicitly', 'ADV'), ('injected', 'VERB'), ('into', 'ADP'), ('a', 'DET'), ('context', 'NOUN'), ('where', 'SCONJ'), ('the', 'DET'), ('browser', 'NOUN'), ('interprets', 'VERB'), ('it', 'PRON'), ('as', 'ADP'), ('executable', 'ADJ'), ('script', 'NOUN'), ('e.g.', 'ADV'), ('through', 'ADP'), ('eval', 'NOUN'), ('document.write', 'PROPN'), ('or', 'CCONJ'), ('innerhtml', 'PROPN'), ('.', 'PUNCT'), ('thus', 'ADV'), ('a', 'DET'), ('reflected', 'VERB'), ('xss', 'PROPN'), ('vulnerability', 'NOUN'), ('on', 'ADP'), ('an', 'DET'), ('api', 'NOUN'), ('endpoint', 'NOUN'), ('requires', 'VERB'), ('that', 'SCONJ'), ('the', 'DET'), ('data', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('api', 'NOUN'), ('be', 'AUX'), ('incorporated', 'VERB'), ('into', 'ADP'), ('a', 'DET'), ('page', 'NOUN'), ('in', 'ADP'), ('such', 'DET'), ('a', 'DET'), ('way', 'NOUN'), ('that', 'SCONJ'), ('user', 'NOUN'), ('-', 'PUNCT'), ('provided', 'VERB'), ('input', 'NOUN'), ('becomes', 'VERB'), ('part', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('executed', 'VERB'), ('javascript', 'PROPN'), ('code', 'NOUN'), ('.', 'PUNCT'), ('for', 'ADP'), ('instance', 'NOUN'), ('if', 'SCONJ'), ('the', 'DET'), ('api', 'NOUN'), ('s', 'PART'), ('json', 'NOUN'), ('response', 'NOUN'), ('is', 'AUX'), ('used', 'VERB'), ('to', 'PART'), ('dynamically', 'ADV'), ('construct', 'VERB'), ('dom', 'NOUN'), ('elements', 'NOUN'), ('without', 'ADP'), ('proper', 'ADJ'), ('sanitization', 'NOUN'), ('like', 'ADP'), ('embedding', 'VERB'), ('it', 'PRON'), ('directly', 'ADV'), ('with', 'ADP'), ('document.write', 'PROPN'), ('or', 'CCONJ'), ('using', 'VERB'), ('eval', 'NOUN'), ('on', 'ADP'), ('the', 'DET'), ('response', 'NOUN'), ('then', 'ADV'), ('an', 'DET'), ('attacker', 'NOUN'), ('can', 'AUX'), ('inject', 'VERB'), ('malicious', 'ADJ'), ('script', 'NOUN'), ('that', 'PRON'), ('executes', 'VERB'), ('when', 'SCONJ'), ('the', 'DET'), ('page', 'NOUN'), ('loads', 'VERB'), ('.', 'PUNCT'), ('a', 'DET'), ('potential', 'ADJ'), ('attack', 'NOUN'), ('scenario', 'NOUN'), ('involves', 'VERB'), ('a', 'DET'), ('search', 'NOUN'), ('feature', 'NOUN'), ('where', 'SCONJ'), ('the', 'DET'), ('user', 'NOUN'), ('input', 'NOUN'), ('is', 'AUX'), ('reflected', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('url', 'NOUN'), ('and', 'CCONJ'), ('then', 'ADV'), ('passed', 'VERB'), ('to', 'ADP'), ('an', 'DET'), ('api', 'NOUN'), ('endpoint', 'NOUN' ...
# Named Entities :
# [('standard html', 'GPE')]
#
# 🔹 Texte original 3 :
# dom clobbering occurs when an object property name in the document object model dom is overwritten by a malicious property allowing the attacker to bypass security checks and execute arbitrary code within the target page. in short dom clobbering is about replacing properties of javascript objects with attacker-controlled values. the most common scenario is using query string parameters to overwrite existing window.location. properties or other object properties. by manipulating these properties an attacker can redirect users to a malicious site steal session cookies or other sensitive information and execute arbitrary scripts on the victim s machine. to mitigate this vulnerability developers should ensure that they validate all user inputs before processing them in their applications. additionally using content security policies csp will help prevent cross-site scripting attacks by preventing unauthorized script execution. by implementing these safeguards developers can significantly reduce the risk of dom clobbering vulnerabilities and protect their users from malicious scripts running on web pages. the concept is similar to the javascript tostring property being overwritten with a function in order to bypass same-origin policy checks but it is not exactly the same technique. an attacker who finds that their reflected xss attempts are being sanitized can look for dom properties to overwrite to gain control over event handlers or other functions used by the target application. the following example shows how an attacker could potentially clobber a property in order to bypass sanitization checks and execute malicious code on a victim s machine. this example assumes that the vulnerable page uses the location.hash value as a url parameter for loading content but performs some type of input validation or sanitation before using it: var hash window.location.hash if hash null hash.length 0 loadcontent hash the attacker could then inject malicious code by setting window.location.hash to be something like alert xss which would result in the following script being executed after validation: alert xss however because of the input validation or sanitation this might not work. so instead the attacker sets location.hash to a value that will overwrite a dom property such as location.hash a . this causes the loadcontent function to execute the script stored in window.location.hash instead of loading content from the specified url.
#
# POS Tags :
# [('dom', 'NOUN'), ('clobbering', 'NOUN'), ('occurs', 'VERB'), ('when', 'SCONJ'), ('an', 'DET'), ('object', 'NOUN'), ('property', 'NOUN'), ('name', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('document', 'NOUN'), ('object', 'NOUN'), ('model', 'NOUN'), ('dom', 'PROPN'), ('is', 'AUX'), ('overwritten', 'VERB'), ('by', 'ADP'), ('a', 'DET'), ('malicious', 'ADJ'), ('property', 'NOUN'), ('allowing', 'VERB'), ('the', 'DET'), ('attacker', 'NOUN'), ('to', 'PART'), ('bypass', 'VERB'), ('security', 'NOUN'), ('checks', 'NOUN'), ('and', 'CCONJ'), ('execute', 'VERB'), ('arbitrary', 'ADJ'), ('code', 'NOUN'), ('within', 'ADP'), ('the', 'DET'), ('target', 'NOUN'), ('page', 'NOUN'), ('.', 'PUNCT'), ('in', 'ADP'), ('short', 'ADJ'), ('dom', 'NOUN'), ('clobbering', 'VERB'), ('is', 'AUX'), ('about', 'ADP'), ('replacing', 'VERB'), ('properties', 'NOUN'), ('of', 'ADP'), ('javascript', 'ADJ'), ('objects', 'NOUN'), ('with', 'ADP'), ('attacker', 'NOUN'), ('-', 'PUNCT'), ('controlled', 'VERB'), ('values', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('most', 'ADV'), ('common', 'ADJ'), ('scenario', 'NOUN'), ('is', 'AUX'), ('using', 'VERB'), ('query', 'NOUN'), ('string', 'NOUN'), ('parameters', 'NOUN'), ('to', 'PART'), ('overwrite', 'VERB'), ('existing', 'VERB'), ('window.location', 'NOUN'), ('.', 'PUNCT'), ('properties', 'NOUN'), ('or', 'CCONJ'), ('other', 'ADJ'), ('object', 'NOUN'), ('properties', 'NOUN'), ('.', 'PUNCT'), ('by', 'ADP'), ('manipulating', 'VERB'), ('these', 'DET'), ('properties', 'NOUN'), ('an', 'DET'), ('attacker', 'NOUN'), ('can', 'AUX'), ('redirect', 'VERB'), ('users', 'NOUN'), ('to', 'ADP'), ('a', 'DET'), ('malicious', 'ADJ'), ('site', 'NOUN'), ('steal', 'NOUN'), ('session', 'NOUN'), ('cookies', 'NOUN'), ('or', 'CCONJ'), ('other', 'ADJ'), ('sensitive', 'ADJ'), ('information', 'NOUN'), ('and', 'CCONJ'), ('execute', 'VERB'), ('arbitrary', 'ADJ'), ('scripts', 'NOUN'), ('on', 'ADP'), ('the', 'DET'), ('victim', 'NOUN'), ('s', 'PART'), ('machine', 'NOUN'), ('.', 'PUNCT'), ('to', 'PART'), ('mitigate', 'VERB'), ('this', 'DET'), ('vulnerability', 'NOUN'), ('developers', 'NOUN'), ('should', 'AUX'), ('ensure', 'VERB'), ('that', 'SCONJ'), ('they', 'PRON'), ('validate', 'VERB'), ('all', 'DET'), ('user', 'NOUN'), ('inputs', 'NOUN'), ('before', 'ADP'), ('processing', 'VERB'), ('them', 'PRON'), ('in', 'ADP'), ('their', 'PRON'), ('applications', 'NOUN'), ('.', 'PUNCT'), ('additionally', 'ADV'), ('using', 'VERB'), ('content', 'NOUN'), ('security', 'NOUN'), ('policies', 'NOUN'), ('csp', 'PROPN'), ('will', 'AUX'), ('help', 'VERB'), ('prevent', 'VERB'), ('cross', 'ADJ'), ('-', 'ADJ'), ('site', 'ADJ'), ('scripting', 'NOUN'), ('attacks', 'NOUN'), ('by', 'ADP'), ('preventing', 'VERB'), ('unauthorized', 'ADJ'), ('script', 'NOUN'), ('execution', 'NOUN'), ('.', 'PUNCT'), ('by', 'ADP'), ('implementing', 'VERB'), ('these', 'DET'), ('safeguards', 'NOUN'), ('developers', 'NOUN'), ('can', 'AUX'), ('significantly', 'ADV'), ('reduce', 'VERB'), ('the', 'DET'), ('risk', 'NOUN'), ('of', 'ADP'), ('dom', 'NOUN'), ('clobbering', 'VERB'), ('vulnerabilities', 'NOUN'), ('and', 'CCONJ'), ('protect', 'VERB'), ('their', 'PRON'), ('users', 'NOUN'), ('from', 'ADP'), ('malicious', 'ADJ'), ('scripts', 'NOUN'), ('running', 'VERB'), ('on', 'ADP'), ('web', 'NOUN'), ('pages', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('concept', 'NOUN'), ('is', 'AUX'), ('similar', 'ADJ'), ('to', 'ADP'), ('the', 'DET'), ('javascript', 'ADJ'), ('tostring', 'VERB'), ('property', 'NOUN'), ('being', 'AUX'), ('overwritten', 'VERB'), ('with', 'ADP'), ('a', 'DET'), ('function', 'NOUN'), ('in', 'ADP'), ('order', 'NOUN'), ('to', 'PART'), ('bypass', 'VERB'), ('same', 'ADJ'), ('-', 'PUNCT'), ('origin', 'NOUN'), ('policy', 'NOUN'), ('checks', 'NOUN'), ('but', 'CCONJ'), ('it', 'PRON'), ('is', 'AUX'), ('not', 'PART'), ('exactly', 'ADV'), ('the', 'DET'), ('same', 'ADJ'), ('technique', 'NOUN'), ('.', 'PUNCT'), ('an', 'DET'), ('attacker', 'NOUN'), ('who', 'PRON'), ('finds', 'VERB'), ('that', 'SCONJ'), ('their', 'PRON'), ('reflected' ...
# Named Entities :
# [('0', 'CARDINAL')]
#
# 🔹 Texte original 4 :
# xss attacks are the most dangerous vulnerability to web applications. the problem arises because some application developers do not properly encode data submitted by users before including it in html pages. attackers use this weakness to embed malicious scripts in a page that is displayed to other users. when these victims click on the malicious script their browser will run it and thus allow attackers to steal sensitive information like session cookies or personal data from the user s machine. this kind of attack can cause serious harm as it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users. in addition attackers can also steal sensitive information like session cookies or personal data from the user s machine. this is a very dangerous vulnerability because it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users. in addition attackers can also steal sensitive information like session cookies or personal data from the user s machine. this is a very dangerous vulnerability because it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users. in addition attackers can also steal sensitive information like session cookies or personal data from the user s machine. this is a very dangerous vulnerability because it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users. in addition attackers can also steal sensitive information like session cookies or personal data from the user s machine. this is a very dangerous vulnerability because it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users. in addition attackers can also steal sensitive information like session cookies or personal data from the user s machine. this is a very dangerous vulnerability because it gives an attacker full access to the victim s system via the web application. attackers can use this type of attack to bypass firewalls by embedding malicious scripts in a page that is displayed to other users.
#
# POS Tags :
# [('xss', 'PROPN'), ('attacks', 'NOUN'), ('are', 'AUX'), ('the', 'DET'), ('most', 'ADV'), ('dangerous', 'ADJ'), ('vulnerability', 'NOUN'), ('to', 'ADP'), ('web', 'NOUN'), ('applications', 'NOUN'), ('.', 'PUNCT'), ('the', 'DET'), ('problem', 'NOUN'), ('arises', 'VERB'), ('because', 'SCONJ'), ('some', 'DET'), ('application', 'NOUN'), ('developers', 'NOUN'), ('do', 'AUX'), ('not', 'PART'), ('properly', 'ADV'), ('encode', 'ADJ'), ('data', 'NOUN'), ('submitted', 'VERB'), ('by', 'ADP'), ('users', 'NOUN'), ('before', 'ADP'), ('including', 'VERB'), ('it', 'PRON'), ('in', 'ADP'), ('html', 'PROPN'), ('pages', 'NOUN'), ('.', 'PUNCT'), ('attackers', 'NOUN'), ('use', 'VERB'), ('this', 'DET'), ('weakness', 'NOUN'), ('to', 'PART'), ('embed', 'VERB'), ('malicious', 'ADJ'), ('scripts', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('page', 'NOUN'), ('that', 'PRON'), ('is', 'AUX'), ('displayed', 'VERB'), ('to', 'ADP'), ('other', 'ADJ'), ('users', 'NOUN'), ('.', 'PUNCT'), ('when', 'SCONJ'), ('these', 'DET'), ('victims', 'NOUN'), ('click', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('malicious', 'ADJ'), ('script', 'NOUN'), ('their', 'PRON'), ('browser', 'NOUN'), ('will', 'AUX'), ('run', 'VERB'), ('it', 'PRON'), ('and', 'CCONJ'), ('thus', 'ADV'), ('allow', 'VERB'), ('attackers', 'NOUN'), ('to', 'PART'), ('steal', 'VERB'), ('sensitive', 'ADJ'), ('information', 'NOUN'), ('like', 'ADP'), ('session', 'NOUN'), ('cookies', 'NOUN'), ('or', 'CCONJ'), ('personal', 'ADJ'), ('data', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('user', 'NOUN'), ('s', 'PART'), ('machine', 'NOUN'), ('.', 'PUNCT'), ('this', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('attack', 'NOUN'), ('can', 'AUX'), ('cause', 'VERB'), ('serious', 'ADJ'), ('harm', 'NOUN'), ('as', 'SCONJ'), ('it', 'PRON'), ('gives', 'VERB'), ('an', 'DET'), ('attacker', 'NOUN'), ('full', 'ADJ'), ('access', 'NOUN'), ('to', 'ADP'), ('the', 'DET'), ('victim', 'NOUN'), ('s', 'PART'), ('system', 'NOUN'), ('via', 'ADP'), ('the', 'DET'), ('web', 'NOUN'), ('application', 'NOUN'), ('.', 'PUNCT'), ('attackers', 'NOUN'), ('can', 'AUX'), ('use', 'VERB'), ('this', 'DET'), ('type', 'NOUN'), ('of', 'ADP'), ('attack', 'NOUN'), ('to', 'ADP'), ('bypass', 'NOUN'), ('firewalls', 'NOUN'), ('by', 'ADP'), ('embedding', 'VERB'), ('malicious', 'ADJ'), ('scripts', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('page', 'NOUN'), ('that', 'PRON'), ('is', 'AUX'), ('displayed', 'VERB'), ('to', 'ADP'), ('other', 'ADJ'), ('users', 'NOUN'), ('.', 'PUNCT'), ('in', 'ADP'), ('addition', 'NOUN'), ('attackers', 'NOUN'), ('can', 'AUX'), ('also', 'ADV'), ('steal', 'VERB'), ('sensitive', 'ADJ'), ('information', 'NOUN'), ('like', 'ADP'), ('session', 'NOUN'), ('cookies', 'NOUN'), ('or', 'CCONJ'), ('personal', 'ADJ'), ('data', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('user', 'NOUN'), ('s', 'PART'), ('machine', 'NOUN'), ('.', 'PUNCT'), ('this', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('very', 'ADV'), ('dangerous', 'ADJ'), ('vulnerability', 'NOUN'), ('because', 'SCONJ'), ('it', 'PRON'), ('gives', 'VERB'), ('an', 'DET'), ('attacker', 'NOUN'), ('full', 'ADJ'), ('access', 'NOUN'), ('to', 'ADP'), ('the', 'DET'), ('victim', 'NOUN'), ('s', 'PART'), ('system', 'NOUN'), ('via', 'ADP'), ('the', 'DET'), ('web', 'NOUN'), ('application', 'NOUN'), ('.', 'PUNCT'), ('attackers', 'NOUN'), ('can', 'AUX'), ('use', 'VERB'), ('this', 'DET'), ('type', 'NOUN'), ('of', 'ADP'), ('attack', 'NOUN'), ('to', 'ADP'), ('bypass', 'NOUN'), ('firewalls', 'NOUN'), ('by', 'ADP'), ('embedding', 'VERB'), ('malicious', 'ADJ'), ('scripts', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('page', 'NOUN'), ('that', 'PRON'), ('is', 'AUX'), ('displayed', 'VERB'), ('to', 'ADP'), ('other', 'ADJ'), ('users', 'NOUN'), ('.', 'PUNCT'), ('in', 'ADP'), ('addition', 'NOUN'), ('attackers', 'NOUN'), ('can', 'AUX'), ('also', 'ADV'), ('steal', 'VERB'), ('sensitive', 'ADJ'), ('information', 'NOUN'), ('like', 'ADP'), ('session', 'NOUN'), ('cookies', 'NOUN'), ('or', 'CCONJ'), ('personal', 'ADJ'), ('data', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('u ...
# Named Entities :
# []
#
# 🔹 Texte original 5 :
# this is the first time i will be teaching a class in my career as a cybersecurity specialist. i have 20 years of hands-on experience but this is new territory for me. there are only two other instructors at our company so there s no one to shadow or learn from. the course is titled introduction to ethical hacking and it is an entry-level class aimed at college students who want to enter the cybersecurity field. i have a detailed syllabus with weekly topics reading assignments lab exercises homework and exams already prepared. my biggest concern is being able to keep the students engaged over the course of four months. i also worry about managing classroom discussions and handling questions from students that may be more advanced than the material presented in the class. to prepare for teaching i have been researching adult learning principles and have started a blog where i write weekly on cybersecurity topics to practice my writing style. i plan on using real-world case studies as examples during lectures to make concepts more tangible and relevant. in addition i will incorporate hands-on labs into each module so that students can apply what they ve learned in a controlled environment. my goal is to not only teach the technical aspects of ethical hacking but also help students understand how these skills are applied in real-world scenarios. i want them to leave this class with both theoretical knowledge and practical experience which will give them an edge when seeking entry-level cybersecurity positions. finally i am open to feedback from my students throughout the course so that i can continually improve as a teacher. if they have suggestions for better ways to explain certain concepts or ideas for additional lab exercises i will do my best to accommodate them while still covering all of the required material.
#
# POS Tags :
# [('this', 'PRON'), ('is', 'AUX'), ('the', 'DET'), ('first', 'ADJ'), ('time', 'NOUN'), ('i', 'PRON'), ('will', 'AUX'), ('be', 'AUX'), ('teaching', 'VERB'), ('a', 'DET'), ('class', 'NOUN'), ('in', 'ADP'), ('my', 'PRON'), ('career', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('cybersecurity', 'NOUN'), ('specialist', 'NOUN'), ('.', 'PUNCT'), ('i', 'PRON'), ('have', 'VERB'), ('20', 'NUM'), ('years', 'NOUN'), ('of', 'ADP'), ('hands', 'NOUN'), ('-', 'PUNCT'), ('on', 'ADP'), ('experience', 'NOUN'), ('but', 'CCONJ'), ('this', 'PRON'), ('is', 'AUX'), ('new', 'ADJ'), ('territory', 'NOUN'), ('for', 'ADP'), ('me', 'PRON'), ('.', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('only', 'ADV'), ('two', 'NUM'), ('other', 'ADJ'), ('instructors', 'NOUN'), ('at', 'ADP'), ('our', 'PRON'), ('company', 'NOUN'), ('so', 'SCONJ'), ('there', 'PRON'), ('s', 'VERB'), ('no', 'DET'), ('one', 'NOUN'), ('to', 'PART'), ('shadow', 'VERB'), ('or', 'CCONJ'), ('learn', 'VERB'), ('from', 'ADP'), ('.', 'PUNCT'), ('the', 'DET'), ('course', 'NOUN'), ('is', 'AUX'), ('titled', 'VERB'), ('introduction', 'NOUN'), ('to', 'ADP'), ('ethical', 'ADJ'), ('hacking', 'NOUN'), ('and', 'CCONJ'), ('it', 'PRON'), ('is', 'AUX'), ('an', 'DET'), ('entry', 'NOUN'), ('-', 'PUNCT'), ('level', 'NOUN'), ('class', 'NOUN'), ('aimed', 'VERB'), ('at', 'ADP'), ('college', 'NOUN'), ('students', 'NOUN'), ('who', 'PRON'), ('want', 'VERB'), ('to', 'PART'), ('enter', 'VERB'), ('the', 'DET'), ('cybersecurity', 'NOUN'), ('field', 'NOUN'), ('.', 'PUNCT'), ('i', 'PRON'), ('have', 'VERB'), ('a', 'DET'), ('detailed', 'ADJ'), ('syllabus', 'NOUN'), ('with', 'ADP'), ('weekly', 'ADJ'), ('topics', 'NOUN'), ('reading', 'VERB'), ('assignments', 'NOUN'), ('lab', 'NOUN'), ('exercises', 'NOUN'), ('homework', 'ADJ'), ('and', 'CCONJ'), ('exams', 'NOUN'), ('already', 'ADV'), ('prepared', 'VERB'), ('.', 'PUNCT'), ('my', 'PRON'), ('biggest', 'ADJ'), ('concern', 'NOUN'), ('is', 'AUX'), ('being', 'AUX'), ('able', 'ADJ'), ('to', 'PART'), ('keep', 'VERB'), ('the', 'DET'), ('students', 'NOUN'), ('engaged', 'VERB'), ('over', 'ADP'), ('the', 'DET'), ('course', 'NOUN'), ('of', 'ADP'), ('four', 'NUM'), ('months', 'NOUN'), ('.', 'PUNCT'), ('i', 'PRON'), ('also', 'ADV'), ('worry', 'VERB'), ('about', 'ADP'), ('managing', 'VERB'), ('classroom', 'NOUN'), ('discussions', 'NOUN'), ('and', 'CCONJ'), ('handling', 'VERB'), ('questions', 'NOUN'), ('from', 'ADP'), ('students', 'NOUN'), ('that', 'PRON'), ('may', 'AUX'), ('be', 'AUX'), ('more', 'ADV'), ('advanced', 'ADJ'), ('than', 'ADP'), ('the', 'DET'), ('material', 'NOUN'), ('presented', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('class', 'NOUN'), ('.', 'PUNCT'), ('to', 'PART'), ('prepare', 'VERB'), ('for', 'ADP'), ('teaching', 'NOUN'), ('i', 'PRON'), ('have', 'AUX'), ('been', 'AUX'), ('researching', 'VERB'), ('adult', 'NOUN'), ('learning', 'NOUN'), ('principles', 'NOUN'), ('and', 'CCONJ'), ('have', 'AUX'), ('started', 'VERB'), ('a', 'DET'), ('blog', 'NOUN'), ('where', 'SCONJ'), ('i', 'PRON'), ('write', 'VERB'), ('weekly', 'NOUN'), ('on', 'ADP'), ('cybersecurity', 'NOUN'), ('topics', 'NOUN'), ('to', 'PART'), ('practice', 'VERB'), ('my', 'PRON'), ('writing', 'NOUN'), ('style', 'NOUN'), ('.', 'PUNCT'), ('i', 'PRON'), ('plan', 'VERB'), ('on', 'ADP'), ('using', 'VERB'), ('real', 'ADJ'), ('-', 'PUNCT'), ('world', 'NOUN'), ('case', 'NOUN'), ('studies', 'NOUN'), ('as', 'ADP'), ('examples', 'NOUN'), ('during', 'ADP'), ('lectures', 'NOUN'), ('to', 'PART'), ('make', 'VERB'), ('concepts', 'NOUN'), ('more', 'ADV'), ('tangible', 'ADJ'), ('and', 'CCONJ'), ('relevant', 'ADJ'), ('.', 'PUNCT'), ('in', 'ADP'), ('addition', 'NOUN'), ('i', 'PRON'), ('will', 'AUX'), ('incorporate', 'VERB'), ('hands', 'NOUN'), ('-', 'PUNCT'), ('on', 'ADP'), ('labs', 'NOUN'), ('into', 'ADP'), ('each', 'DET'), ('module', 'NOUN'), ('so', 'SCONJ'), ('that', 'SCONJ'), ('students', 'NOUN'), ('can', 'AUX'), ('apply', 'VERB'), ('what', 'PRON'), ('they', 'PRON'), ('ve', 'AUX'), ('learned', 'VERB'), ('in', 'ADP'), ('a', 'DET'), ('controlled', 'VER ...
# Named Entities :
# [('first', 'ORDINAL'), ('20 years', 'DATE'), ('only two', 'CARDINAL'), ('weekly', 'DATE'), ('four months', 'DATE'), ('weekly', 'DATE')]

# %% [markdown]
# **Feature Extraction: Bag-of-Words (BoW) Vectorization**

# %%
# --- Bag-of-Words ---
bow_vectorizer = CountVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    lowercase=True
)
X_bow = bow_vectorizer.fit_transform(df['assistant_nlp'])
# --- Convertir en DataFrame pour voir les mots et leurs comptes ---
bow_df = pd.DataFrame(
    X_bow.toarray(),
    columns=bow_vectorizer.get_feature_names_out()
)



print("✅ Bag-of-Words terminé")
print("Forme de la matrice BoW :", X_bow.shape)

# --- Somme des occurrences de chaque mot dans tout le corpus ---
word_counts = bow_df.sum().sort_values(ascending=False)
print("\n🔹 Top 20 mots les plus fréquents (Bag-of-Words) :")
print(word_counts.head(20))
# Out:
# ✅ Bag-of-Words terminé
# Forme de la matrice BoW : (2408, 5000)
#
# 🔹 Top 20 mots les plus fréquents (Bag-of-Words) :
# attacker         7985
# attack           6507
# security         5591
# system           5406
# code             4366
# vulnerability    4314
# data             3946
# technique        3938
# user             3909
# process          3852
# like             3752
# malicious        3718
# application      3365
# also             3364
# memory           3167
# used             3120
# using            3074
# not              3011
# use              2810
# exploit          2739
# dtype: int64

# %% [markdown]
# **Feature Extraction: TF-IDF (Term Frequency–Inverse Document Frequency)**

# %%
# --- TF-IDF ---
tfidf_vectorizer = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    lowercase=True
)

X_tfidf = tfidf_vectorizer.fit_transform(df['assistant_nlp'])

# --- Convertir en DataFrame pour visualisation ---
tfidf_df = pd.DataFrame(
    X_tfidf.toarray(),
    columns=tfidf_vectorizer.get_feature_names_out()
)

print("✅ TF-IDF terminé")
print("Forme de la matrice TF-IDF :", X_tfidf.shape)

# --- Somme des poids TF-IDF de chaque mot sur tout le corpus ---
tfidf_scores = tfidf_df.sum().sort_values(ascending=False)
print("\n🔹 Top 20 mots les plus importants (TF-IDF) :")
print(tfidf_scores.head(20))
# Out:
# ✅ TF-IDF terminé
# Forme de la matrice TF-IDF : (2408, 5000)
#
# 🔹 Top 20 mots les plus importants (TF-IDF) :
# attacker         100.199348
# attack            85.525722
# system            76.111125
# security          72.941948
# code              69.822181
# vulnerability     68.555159
# user              67.024645
# memory            64.612937
# process           62.384845
# application       60.202674
# technique         59.485871
# data              59.180868
# malicious         55.930473
# like              53.903625
# threat            52.321803
# network           51.984234
# malware           48.919288
# exploit           48.479645
# access            48.329736
# token             46.761626
# dtype: float64

# %% [markdown]
# **Visualization Setup: Configure Seaborn Styl**

# %%
sns.set(style="whitegrid")

# %% [markdown]
# **Top 20 mots Bag-of-Words**

# %%
# --- Top 20 mots Bag-of-Words ---
top_bow = word_counts.head(20)

plt.figure(figsize=(12,6))
sns.barplot(x=top_bow.values, y=top_bow.index, palette="viridis")
plt.title("Top 20 mots les plus fréquents (Bag-of-Words)")
plt.xlabel("Nombre d'occurrences")
plt.ylabel("Mots")
plt.show()

# %% [markdown]
# **Top 20 mots TF-IDF**

# %%
# --- Top 20 mots TF-IDF ---
top_tfidf = tfidf_scores.head(20)

plt.figure(figsize=(12,6))
sns.barplot(x=top_tfidf.values, y=top_tfidf.index, palette="magma")
plt.title("Top 20 mots les plus importants (TF-IDF)")
plt.xlabel("Score TF-IDF total")
plt.ylabel("Mots")
plt.show()

# %%
df
# Out:
#                                                  system  \
# 0     You are a highly specialized AI assistant for ...
# 1     You are a highly specialized AI assistant for ...
# 2     You are a highly specialized AI assistant for ...
# 3     You are a highly specialized AI assistant for ...
# 4     You are a highly specialized AI assistant for ...
# ...                                                 ...
# 2406  You are a highly specialized AI assistant for ...
# 2407  You are a highly specialized AI assistant for ...
# 2408  You are a highly specialized AI assistant for ...
# 2409  You are a highly specialized AI assistant for ...
# 2410  You are a highly specialized AI assistant for ...
#
#                                                    user  \
# 0     Explain the fundamental data flow of a Reflect...
# 1     How does a Reflected XSS vulnerability in an A...
# 2     What is \"DOM Clobbering\" and how can it be u...
# 3     Explain the concept of \"filter evasion\" in t...
# 4     How can character encoding (e.g., UTF-7, UTF-1...
# ...                                                 ...
# 2406  How can researchers design hardware implants t...
# 2407  What is the modulation scheme selection proces...
# 2408  How does one construct miniaturized PLC implan...
# 2409  What are the techniques for implementing sprea...
# 2410  How can one develop PLC implant firmware that ...
#
#                                               assistant  \
# 0     Reflected XSS attacks occur when an attacker s...
# 1     The difference between reflected cross-site sc...
# 2     DOM Clobbering occurs when an object property ...
# 3     XSS attacks are the most dangerous vulnerabili...
# 4     This is the first time I will be teaching a cl...
# ...                                                 ...
# 2406  The creation of hardware implants capable of e...
# 2407  The modulation scheme selection is a key desig...
# 2408  The most effective way to create an implant in...
# 2409  Spread spectrum modulation techniques can be u...
# 2410  The industrial control system (ICS) network is...
#
#                                            system_clean  \
# 0     you are a highly specialized ai assistant for ...
# 1     you are a highly specialized ai assistant for ...
# 2     you are a highly specialized ai assistant for ...
# 3     you are a highly specialized ai assistant for ...
# 4     you are a highly specialized ai assistant for ...
# ...                                                 ...
# 2406  you are a highly specialized ai assistant for ...
# 2407  you are a highly specialized ai assistant for ...
# 2408  you are a highly specialized ai assistant for ...
# 2409  you are a highly specialized ai assistant for ...
# 2410  you are a highly specialized ai assistant for ...
#
#                                              user_clean  \
# 0     explain the fundamental data flow of a reflect...
# 1     how does a reflected xss vulnerability in an a...
# 2     what is dom clobbering and how can it be used ...
# 3     explain the concept of filter evasion in the c...
# 4     how can character encoding e.g. utf-7 utf-16 c...
# ...                                                 ...
# 2406  how can researchers design hardware implants t...
# 2407  what is the modulation scheme selection proces...
# 2408  how does one construct miniaturized plc implan...
# 2409  what are the techniques for implementing sprea...
# 2410  how can one develop plc implant firmware that ...
#
#                                         assistant_clean  \
# 0     reflected xss attacks occur when an attacker s...
# 1     the difference between reflected cross-site sc...
# 2     dom clobbering occurs when an object property ...
# 3     xss attacks are the most dangerous vulnerabili...
# 4     this is the first time i will be teaching a cl...
# ...                                                 ...
# 2406  the creation of hardware implants capable of e...
# 2407  the modulation scheme selection is a key desig...
# 2408  the most effective way to create an implant in...
# 2409  spread spectrum modulation techniques can be u...
# 2410  the industrial control system ics network is t...
#
#                                           assistant_nlp
# 0     reflected xss attack occur attacker sends requ...
# 1     difference reflected scripting xss vulnerabili...
# 2     dom clobbering occurs object property name doc...
# 3     xss attack dangerous vulnerability web applica...
# 4     first time teaching class career cybersecurity...
# ...                                                 ...
# 2406  creation hardware implant capable establishing...
# 2407  modulation scheme selection key design decisio...
# 2408  effective way create implant plc embed existin...
# 2409  spread spectrum modulation technique used modu...
# 2410  industrial control system ic network lifeblood...
#
# [2408 rows x 7 columns]

# %% [markdown]
# # **Tokanization**

# %%
# --- Ensure required NLTK resources are available ---
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt', quiet=True)

# --- Apply tokenization to your dataset ---
# This uses your existing `custom_stopwords` from the notebook

df["tokens"] = df["user_clean"].apply(
    lambda x: [
        tok.lower() for tok in word_tokenize(str(x))
        if tok.isalnum() and tok.lower() not in custom_stopwords
    ]
)

print("✅ Tokenization complete. Sample tokens:")
print(df[["user_clean", "tokens"]].head())
# Out:
# ✅ Tokenization complete. Sample tokens:
#                                           user_clean  \
# 0  explain the fundamental data flow of a reflect...
# 1  how does a reflected xss vulnerability in an a...
# 2  what is dom clobbering and how can it be used ...
# 3  explain the concept of filter evasion in the c...
# 4  how can character encoding e.g. utf-7 utf-16 c...
#
#                                               tokens
# 0  [explain, fundamental, data, flow, reflected, ...
# 1  [reflected, xss, vulnerability, api, endpoint,...
# 2  [dom, clobbering, used, escalate, enable, refl...
# 3  [explain, concept, filter, evasion, context, r...
# 4  [character, encoding, abused, bypass, xss, fil...

# %%
df
# Out:
#                                                  system  \
# 0     You are a highly specialized AI assistant for ...
# 1     You are a highly specialized AI assistant for ...
# 2     You are a highly specialized AI assistant for ...
# 3     You are a highly specialized AI assistant for ...
# 4     You are a highly specialized AI assistant for ...
# ...                                                 ...
# 2406  You are a highly specialized AI assistant for ...
# 2407  You are a highly specialized AI assistant for ...
# 2408  You are a highly specialized AI assistant for ...
# 2409  You are a highly specialized AI assistant for ...
# 2410  You are a highly specialized AI assistant for ...
#
#                                                    user  \
# 0     Explain the fundamental data flow of a Reflect...
# 1     How does a Reflected XSS vulnerability in an A...
# 2     What is \"DOM Clobbering\" and how can it be u...
# 3     Explain the concept of \"filter evasion\" in t...
# 4     How can character encoding (e.g., UTF-7, UTF-1...
# ...                                                 ...
# 2406  How can researchers design hardware implants t...
# 2407  What is the modulation scheme selection proces...
# 2408  How does one construct miniaturized PLC implan...
# 2409  What are the techniques for implementing sprea...
# 2410  How can one develop PLC implant firmware that ...
#
#                                               assistant  \
# 0     Reflected XSS attacks occur when an attacker s...
# 1     The difference between reflected cross-site sc...
# 2     DOM Clobbering occurs when an object property ...
# 3     XSS attacks are the most dangerous vulnerabili...
# 4     This is the first time I will be teaching a cl...
# ...                                                 ...
# 2406  The creation of hardware implants capable of e...
# 2407  The modulation scheme selection is a key desig...
# 2408  The most effective way to create an implant in...
# 2409  Spread spectrum modulation techniques can be u...
# 2410  The industrial control system (ICS) network is...
#
#                                            system_clean  \
# 0     you are a highly specialized ai assistant for ...
# 1     you are a highly specialized ai assistant for ...
# 2     you are a highly specialized ai assistant for ...
# 3     you are a highly specialized ai assistant for ...
# 4     you are a highly specialized ai assistant for ...
# ...                                                 ...
# 2406  you are a highly specialized ai assistant for ...
# 2407  you are a highly specialized ai assistant for ...
# 2408  you are a highly specialized ai assistant for ...
# 2409  you are a highly specialized ai assistant for ...
# 2410  you are a highly specialized ai assistant for ...
#
#                                              user_clean  \
# 0     explain the fundamental data flow of a reflect...
# 1     how does a reflected xss vulnerability in an a...
# 2     what is dom clobbering and how can it be used ...
# 3     explain the concept of filter evasion in the c...
# 4     how can character encoding e.g. utf-7 utf-16 c...
# ...                                                 ...
# 2406  how can researchers design hardware implants t...
# 2407  what is the modulation scheme selection proces...
# 2408  how does one construct miniaturized plc implan...
# 2409  what are the techniques for implementing sprea...
# 2410  how can one develop plc implant firmware that ...
#
#                                         assistant_clean  \
# 0     reflected xss attacks occur when an attacker s...
# 1     the difference between reflected cross-site sc...
# 2     dom clobbering occurs when an object property ...
# 3     xss attacks are the most dangerous vulnerabili...
# 4     this is the first time i will be teaching a cl...
# ...                                                 ...
# 2406  the creation of hardware implants capable of e...
# 2407  the modulation scheme selection is a key desig...
# 2408  the most effective way to create an implant in...
# 2409  spread spectrum modulation techniques can be u...
# 2410  the industrial control system ics network is t...
#
#                                           assistant_nlp  \
# 0     reflected xss attack occur attacker sends requ...
# 1     difference reflected scripting xss vulnerabili...
# 2     dom clobbering occurs object property name doc...
# 3     xss attack dangerous vulnerability web applica...
# 4     first time teaching class career cybersecurity...
# ...                                                 ...
# 2406  creation hardware implant capable establishing...
# 2407  modulation scheme selection key design decisio...
# 2408  effective way create implant plc embed existin...
# 2409  spread spectrum modulation technique used modu...
# 2410  industrial control system ic network lifeblood...
#
#                                                  tokens
# 0     [explain, fundamental, data, flow, reflected, ...
# 1     [reflected, xss, vulnerability, api, endpoint,...
# 2     [dom, clobbering, used, escalate, enable, refl...
# 3     [explain, concept, filter, evasion, context, r...
# 4     [character, encoding, abused, bypass, xss, fil...
# ...                                                 ...
# 2406  [researchers, design, hardware, implants, esta...
# 2407  [modulation, scheme, selection, process, imple...
# 2408  [one, construct, miniaturized, plc, implants, ...
# 2409  [techniques, implementing, spread, spectrum, p...
# 2410  [one, develop, plc, implant, firmware, adapts,...
#
# [2408 rows x 8 columns]

# %% [markdown]
# **Visualization of Frequent Words in User Texts (WordCloud for Cybersecurity Incidents)**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Toujours nettoyer les valeurs nulles/NaN avant de joindre le texte
all_text = " ".join(df['user_clean'].fillna('').astype(str).tolist())

# Création et affichage du WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud - Incidents Cybersécurité', fontsize=16)
plt.show()

# %% [markdown]
# # **SBERT**

# %%
from sklearn.cluster import KMeans
import numpy as np

# Check if the 'embedding_sbert' column exists
if 'embedding_sbert' in df.columns:
    # Extract SBERT embeddings
    X_sbert = np.array(df['embedding_sbert'].tolist())

    # Use the optimal number of clusters found previously for TF-IDF clustering
    # If you skipped the Elbow method for TF-IDF, you might want to run it here for SBERT
    # For now, we reuse the number found for TF-IDF (optimal_n_clusters)
    n_clusters_sbert = optimal_n_clusters # Reusing the variable from TF-IDF clustering step

    print(f"Applying K-Means clustering with {n_clusters_sbert} clusters using SBERT embeddings.")

    # Instantiate and fit KMeans model
    kmeans_sbert = KMeans(n_clusters=n_clusters_sbert, random_state=42, n_init=10)
    df['sbert_cluster'] = kmeans_sbert.fit_predict(X_sbert)

    # Print cluster distribution
    print("\nDistribution of clusters based on SBERT embeddings:")
    print(df['sbert_cluster'].value_counts())

    # Optionally, print example texts for each cluster
    print("\nExample texts for each SBERT cluster:")
    for cluster_id in range(n_clusters_sbert):
        print(f"\nCluster {cluster_id}:")
        # Get up to 3 examples from this cluster
        examples = df[df['sbert_cluster'] == cluster_id]['user_clean'].head(3).tolist()
        for example in examples:
            print(f"- {example[:150]}...") # Print first 150 characters

else:
    print("The 'embedding_sbert' column is missing. Please ensure SBERT embeddings are generated before running this step.")
# Out:
# The 'embedding_sbert' column is missing. Please ensure SBERT embeddings are generated before running this step.

# %% [markdown]
# **Text Representation with SBERT and Topic Discovery via K-Means**

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.cluster import KMeans


# Load a Sentence-Transformer model
try:
    # Using the previously defined model name if available, otherwise use a default
    sbert_model_name = args.sbert_model if 'args' in locals() and args.sbert_model else 'all-MiniLM-L6-v2'
    model_sbert = SentenceTransformer(sbert_model_name)
    print(f"Sentence-Transformer model '{sbert_model_name}' loaded successfully.")
except Exception as e:
    print(f"Error loading Sentence-Transformer model: {e}")
    model_sbert = None


if model_sbert and 'user_clean' in df.columns:
    # Generate SBERT embeddings
    print("\nGenerating SBERT embeddings...")
    # Ensure 'processed_text' is treated as string and handle potential NaNs
    df['embedding_sbert'] = df['user_clean'].fillna('').astype(str).apply(lambda x: model_sbert.encode(x))
    print("SBERT embeddings generated.")

    # Display first 10 values of the first embedding
    if not df.empty and 'embedding_sbert' in df.columns and len(df['embedding_sbert'].iloc[0]) > 0:
         print("SBERT Embedding (first 10 values):", df['embedding_sbert'].iloc[0][:10])
    else:
        print("Could not display SBERT embedding.")

    # Now apply K-Means clustering on the generated SBERT embeddings
    print("\nApplying K-Means clustering on SBERT embeddings...")
    X_sbert = np.array(df['embedding_sbert'].tolist())

    # Use the optimal number of clusters found previously for TF-IDF clustering
    # If optimal_n_clusters is not defined, set a default
    n_clusters_sbert = optimal_n_clusters if 'optimal_n_clusters' in locals() else 8 # Default to 8 if not defined

    print(f"Using {n_clusters_sbert} clusters for K-Means on SBERT embeddings.")

    # Instantiate and fit KMeans model
    kmeans_sbert = KMeans(n_clusters=n_clusters_sbert, random_state=42, n_init=10)
    df['sbert_cluster'] = kmeans_sbert.fit_predict(X_sbert)

    # Print cluster distribution
    print("\nDistribution of clusters based on SBERT embeddings:")
    print(df['sbert_cluster'].value_counts())

    # Optionally, print example texts for each cluster
    print("\nExample texts for each SBERT cluster:")
    for cluster_id in range(n_clusters_sbert):
        print(f"\nCluster {cluster_id}:")
        # Get up to 3 examples from this cluster
        examples = df[df['sbert_cluster'] == cluster_id]['user_clean'].head(3).tolist()
        for example in examples:
            print(f"- {example[:150]}...") # Print first 150 characters


else:
    print("\nCould not generate SBERT embeddings or 'processed_text' column is missing. Cannot proceed with clustering.")
# Out:
# Sentence-Transformer model 'all-MiniLM-L6-v2' loaded successfully.
#
# Generating SBERT embeddings...
# SBERT embeddings generated.
# SBERT Embedding (first 10 values): [-0.032126    0.01534218  0.0131459  -0.01063395  0.05395245 -0.06509252
#   0.09597041 -0.00571864  0.00109669 -0.01965991]
#
# Applying K-Means clustering on SBERT embeddings...
# Using 8 clusters for K-Means on SBERT embeddings.
#
# Distribution of clusters based on SBERT embeddings:
# sbert_cluster
# 5    419
# 7    388
# 0    375
# 6    314
# 1    271
# 2    248
# 4    246
# 3    147
# Name: count, dtype: int64
#
# Example texts for each SBERT cluster:
#
# Cluster 0:
# - how can an lfi vulnerability be used to cause a denial of service dos provide an example of a file on a linux system that when included would hang or ...
# - what is the expect:// wrapper explain how if the expect extension is installed an attacker can use it to execute arbitrary shell commands directly via...
# - how would you use lfi to access file descriptors available to the running web server process which wrapper or pseudo-filesystem /proc/self/fd/... woul...
#
# Cluster 1:
# - how can an attacker use different number bases e.g. hexadecimal 0x... or string concatenation functions to obfuscate a payload and evade filters...
# - describe how an attacker can use lfi to enumerate running processes and discover sensitive information on a linux server. which pseudo-filesystem woul...
# - describe a methodology for manually discovering and confirming an insecure deserialization vulnerability. your answer should cover identifying potenti...
#
# Cluster 2:
# - you are conducting a black-box penetration test. describe your step-by-step methodology to test an endpoint for xxe starting from basic detection to a...
# - when performing a secure code review what specific classes methods and configuration settings would you look for in an application s source code to id...
# - why is manual testing often involving two different user accounts one of the most effective ways to discover idor vulnerabilities why do automated sta...
#
# Cluster 3:
# - explain the fundamental data flow of a reflected xss attack. describe the journey of the malicious payload from the attacker to the victim s browser d...
# - how does a reflected xss vulnerability in an api endpoint that returns a content-type of application/json differ from one in a standard html page expl...
# - what is dom clobbering and how can it be used to escalate or enable a reflected xss payload provide a conceptual example of how an attacker might use ...
#
# Cluster 4:
# - explain the synchronizer token pattern in detail. describe the lifecycle of a stateful server-side anti-csrf token from generation to validation. what...
# - compare the double submit cookie pattern with the synchronizer token pattern. what are the primary advantages e.g. statelessness and disadvantages e.g...
# - imagine an application that allows changing a user s email address via a post request but requires the user s current password for confirmation. how d...
#
# Cluster 5:
# - how do tools like sqlmap automate the process of detecting and exploiting time-based blind sqli explain the underlying logic it uses to measure respon...
# - how would you write a waf rule to detect or block xxe attacks what are the challenges in writing a rule that is effective without generating a high nu...
# - design a multi-layered rate-limiting strategy for a public api. your strategy should consider limits based on ip address api key and specific user acc...
#
# Cluster 6:
# - explain the fundamental difference between an error-based sqli and a union-based sqli. describe a scenario where one would be preferable over the othe...
# - what is a stacked query injection e.g. using explain why this technique is often one of the most powerful and also one of the most frequently blocked....
# - how would you manually perform a union-based sqli when the number of columns in the original query is unknown detail the step-by-step process using or...
#
# Cluster 7:
# - can zip or zlib wrappers zip:// compress.zlib:// be used to exploit an lfi describe a plausible scenario for example involving a .zip archive on the t...
# - what is a template sandbox explain its purpose as a security mechanism. then describe a high-level approach an attacker might take to find weaknesses ...
# - what are the specific memory corruption vulnerabilities in tls libraries that enable mitm attackers to inject malicious code during the handshake proc...

# %% [markdown]
# **Exemple**

# %%
# Print example texts for each SBERT cluster, handling potential non-string types
print("\nExample texts for each SBERT cluster (with error handling):")
for cluster_id in range(n_clusters_sbert):
    print(f"\nCluster {cluster_id}:")
    # Get up to 3 examples from this cluster
    examples = df[df['sbert_cluster'] == cluster_id]['user_clean'].head(3).tolist()
    for example in examples:
        if isinstance(example, str):
            print(f"- {example[:150]}...") # Print first 150 characters of string examples
        else:
            print(f"- (Non-string example: {example})...") # Indicate non-string examples
# Out:
# Example texts for each SBERT cluster (with error handling):
#
# Cluster 0:
# - how can an lfi vulnerability be used to cause a denial of service dos provide an example of a file on a linux system that when included would hang or ...
# - what is the expect:// wrapper explain how if the expect extension is installed an attacker can use it to execute arbitrary shell commands directly via...
# - how would you use lfi to access file descriptors available to the running web server process which wrapper or pseudo-filesystem /proc/self/fd/... woul...
#
# Cluster 1:
# - how can an attacker use different number bases e.g. hexadecimal 0x... or string concatenation functions to obfuscate a payload and evade filters...
# - describe how an attacker can use lfi to enumerate running processes and discover sensitive information on a linux server. which pseudo-filesystem woul...
# - describe a methodology for manually discovering and confirming an insecure deserialization vulnerability. your answer should cover identifying potenti...
#
# Cluster 2:
# - you are conducting a black-box penetration test. describe your step-by-step methodology to test an endpoint for xxe starting from basic detection to a...
# - when performing a secure code review what specific classes methods and configuration settings would you look for in an application s source code to id...
# - why is manual testing often involving two different user accounts one of the most effective ways to discover idor vulnerabilities why do automated sta...
#
# Cluster 3:
# - explain the fundamental data flow of a reflected xss attack. describe the journey of the malicious payload from the attacker to the victim s browser d...
# - how does a reflected xss vulnerability in an api endpoint that returns a content-type of application/json differ from one in a standard html page expl...
# - what is dom clobbering and how can it be used to escalate or enable a reflected xss payload provide a conceptual example of how an attacker might use ...
#
# Cluster 4:
# - explain the synchronizer token pattern in detail. describe the lifecycle of a stateful server-side anti-csrf token from generation to validation. what...
# - compare the double submit cookie pattern with the synchronizer token pattern. what are the primary advantages e.g. statelessness and disadvantages e.g...
# - imagine an application that allows changing a user s email address via a post request but requires the user s current password for confirmation. how d...
#
# Cluster 5:
# - how do tools like sqlmap automate the process of detecting and exploiting time-based blind sqli explain the underlying logic it uses to measure respon...
# - how would you write a waf rule to detect or block xxe attacks what are the challenges in writing a rule that is effective without generating a high nu...
# - design a multi-layered rate-limiting strategy for a public api. your strategy should consider limits based on ip address api key and specific user acc...
#
# Cluster 6:
# - explain the fundamental difference between an error-based sqli and a union-based sqli. describe a scenario where one would be preferable over the othe...
# - what is a stacked query injection e.g. using explain why this technique is often one of the most powerful and also one of the most frequently blocked....
# - how would you manually perform a union-based sqli when the number of columns in the original query is unknown detail the step-by-step process using or...
#
# Cluster 7:
# - can zip or zlib wrappers zip:// compress.zlib:// be used to exploit an lfi describe a plausible scenario for example involving a .zip archive on the t...
# - what is a template sandbox explain its purpose as a security mechanism. then describe a high-level approach an attacker might take to find weaknesses ...
# - what are the specific memory corruption vulnerabilities in tls libraries that enable mitm attackers to inject malicious code during the handshake proc...

# %%
# Examine the content of each SBERT cluster
print("\nExamining SBERT Cluster Content:")
for cluster_id in sorted(df['sbert_cluster'].unique()):
    print(f"\n--- Cluster {cluster_id} ---")
    cluster_texts = df[df['sbert_cluster'] == cluster_id]['user_clean'].fillna('').astype(str).tolist()
    print(f"Number of documents in cluster: {len(cluster_texts)}")

    # Print a sample of texts from the cluster
    print("Sample texts:")
    for i, text in enumerate(cluster_texts[:5]): # Print first 5 texts
        print(f"{i+1}. {text[:200]}...") # Print first 200 characters

    # Optional: Could add keyword extraction here if needed
    # from keybert import KeyBERT
    # kw_model = KeyBERT()
    # keywords = kw_model.extract_keywords(" ".join(cluster_texts), keyphrase_ngram_range=(1, 2), stop_words='english', top_n=10)
    # print("Top keywords:", keywords)
# Out:
# Examining SBERT Cluster Content:
#
# --- Cluster 0 ---
# Number of documents in cluster: 375
# Sample texts:
# 1. how can an lfi vulnerability be used to cause a denial of service dos provide an example of a file on a linux system that when included would hang or crash the application....
# 2. what is the expect:// wrapper explain how if the expect extension is installed an attacker can use it to execute arbitrary shell commands directly via an lfi vulnerability....
# 3. how would you use lfi to access file descriptors available to the running web server process which wrapper or pseudo-filesystem /proc/self/fd/... would you use and what might you find...
# 4. what is a command injection vulnerability provide a scenario where an api endpoint that interacts with an underlying system command could be exploited....
# 5. how do apts achieve and maintain persistence describe three distinct persistence mechanisms on a windows system ranging from simple e.g. a scheduled task to advanced e.g. a wmi event subscription or a...
#
# --- Cluster 1 ---
# Number of documents in cluster: 271
# Sample texts:
# 1. how can an attacker use different number bases e.g. hexadecimal 0x... or string concatenation functions to obfuscate a payload and evade filters...
# 2. describe how an attacker can use lfi to enumerate running processes and discover sensitive information on a linux server. which pseudo-filesystem would they target provide an example path....
# 3. describe a methodology for manually discovering and confirming an insecure deserialization vulnerability. your answer should cover identifying potential data entry points recognizing serialized data f...
# 4. what is a rootkit explain how a kernel-level rootkit can hide an apt s presence files processes network connections on a compromised system making it extremely difficult to detect....
# 5. what is steganography describe a scenario where an apt group could use steganography to exfiltrate small amounts of highly sensitive data hidden within seemingly benign image or video files....
#
# --- Cluster 2 ---
# Number of documents in cluster: 248
# Sample texts:
# 1. you are conducting a black-box penetration test. describe your step-by-step methodology to test an endpoint for xxe starting from basic detection to attempting oob exfiltration....
# 2. when performing a secure code review what specific classes methods and configuration settings would you look for in an application s source code to identify potential xxe vulnerabilities provide examp...
# 3. why is manual testing often involving two different user accounts one of the most effective ways to discover idor vulnerabilities why do automated static sast and dynamic dast scanners often struggle ...
# 4. create a checklist for a developer to follow to prevent idor vulnerabilities. your list should include at least five key principles or actions....
# 5. how would you write a regression test to ensure a previously discovered idor vulnerability does not reappear in the codebase...
#
# --- Cluster 3 ---
# Number of documents in cluster: 147
# Sample texts:
# 1. explain the fundamental data flow of a reflected xss attack. describe the journey of the malicious payload from the attacker to the victim s browser detailing each step including the role of the web s...
# 2. how does a reflected xss vulnerability in an api endpoint that returns a content-type of application/json differ from one in a standard html page explain the conditions under which a json response can...
# 3. what is dom clobbering and how can it be used to escalate or enable a reflected xss payload provide a conceptual example of how an attacker might use clobbering to bypass sanitization logic or create ...
# 4. explain the concept of filter evasion in the context of reflected xss. describe at least three distinct techniques an attacker could use to bypass a waf or a server-side filter that attempts to block ...
# 5. how can character encoding e.g. utf-7 utf-16 cesu-8 be abused to bypass xss filters explain the mechanism behind such an attack and what server/browser configurations would make it possible....
#
# --- Cluster 4 ---
# Number of documents in cluster: 246
# Sample texts:
# 1. explain the synchronizer token pattern in detail. describe the lifecycle of a stateful server-side anti-csrf token from generation to validation. what are the essential security properties this token ...
# 2. compare the double submit cookie pattern with the synchronizer token pattern. what are the primary advantages e.g. statelessness and disadvantages e.g. security weaknesses of the double submit cookie ...
# 3. imagine an application that allows changing a user s email address via a post request but requires the user s current password for confirmation. how does this design feature mitigate the risk of a sim...
# 4. explain how the saml security assertion markup language authentication protocol can be vulnerable to xxe. what is the potential impact of a successful xxe attack against a saml identity provider or se...
# 5. in a microservices architecture where data ownership and authorization logic might be distributed across multiple services what new challenges arise for preventing idor how can a central authorization...
#
# --- Cluster 5 ---
# Number of documents in cluster: 419
# Sample texts:
# 1. how do tools like sqlmap automate the process of detecting and exploiting time-based blind sqli explain the underlying logic it uses to measure response times and account for network jitter....
# 2. how would you write a waf rule to detect or block xxe attacks what are the challenges in writing a rule that is effective without generating a high number of false positives...
# 3. design a multi-layered rate-limiting strategy for a public api. your strategy should consider limits based on ip address api key and specific user account to provide a fair and secure service....
# 4. in a microservices architecture what is inter-service communication why is securing traffic between services east-west traffic just as important as securing traffic from the public internet north-sout...
# 5. explain the algorithm confusion attack rs256 to hs256 in detail. your explanation must cover:...
#
# --- Cluster 6 ---
# Number of documents in cluster: 314
# Sample texts:
# 1. explain the fundamental difference between an error-based sqli and a union-based sqli. describe a scenario where one would be preferable over the other for data exfiltration....
# 2. what is a stacked query injection e.g. using explain why this technique is often one of the most powerful and also one of the most frequently blocked. describe what specific database configurations or...
# 3. how would you manually perform a union-based sqli when the number of columns in the original query is unknown detail the step-by-step process using order by and union select to first determine the col...
# 4. explain the concept of type juggling in the context of sqli. how can a vulnerability in a loosely typed language like php lead to a waf bypass or an exploitable condition in a where clause that compar...
# 5. what are inline comments -- or and block comments / / and how are they used differently to truncate or manipulate a sql query during an injection attack provide a query example for each....
#
# --- Cluster 7 ---
# Number of documents in cluster: 388
# Sample texts:
# 1. can zip or zlib wrappers zip:// compress.zlib:// be used to exploit an lfi describe a plausible scenario for example involving a .zip archive on the target server....
# 2. what is a template sandbox explain its purpose as a security mechanism. then describe a high-level approach an attacker might take to find weaknesses in the sandbox configuration or known bypasses to ...
# 3. what are the specific memory corruption vulnerabilities in tls libraries that enable mitm attackers to inject malicious code during the handshake process and how do you exploit heap spray techniques i...
# 4. what is the mathematical framework for designing covert channels that exploit speculative execution vulnerabilities in modern processors and how do you quantify the information leakage through branch ...
# 5. how would you construct a covert channel using gpu memory access patterns that exploits the unified memory architecture in modern heterogeneous computing systems while evading performance counter-base...

# %% [markdown]
# **Number of cclusters and exemple**

# %%
# Continue examining the content of the remaining SBERT clusters
print(f"\n--- Cluster 4 ---")
cluster_texts = df[df['sbert_cluster'] == 4]['user_clean'].fillna('').astype(str).tolist()
print(f"Number of documents in cluster: {len(cluster_texts)}")

# Print a sample of texts from the cluster
print("Sample texts:")
for i, text in enumerate(cluster_texts[:5]): # Print first 5 texts
    print(f"{i+1}. {text[:200]}...") # Print first 200 characters

print(f"\n--- Cluster 5 ---")
cluster_texts = df[df['sbert_cluster'] == 5]['user_clean'].fillna('').astype(str).tolist()
print(f"Number of documents in cluster: {len(cluster_texts)}")

# Print a sample of texts from the cluster
print("Sample texts:")
for i, text in enumerate(cluster_texts[:5]): # Print first 5 texts
    print(f"{i+1}. {text[:200]}...") # Print first 200 characters

print(f"\n--- Cluster 6 ---")
cluster_texts = df[df['sbert_cluster'] == 6]['user_clean'].fillna('').astype(str).tolist()
print(f"Number of documents in cluster: {len(cluster_texts)}")

# Print a sample of texts from the cluster
print("Sample texts:")
for i, text in enumerate(cluster_texts[:5]): # Print first 5 texts
    print(f"{i+1}. {text[:200]}...") # Print first 200 characters

print(f"\n--- Cluster 7 ---")
cluster_texts = df[df['sbert_cluster'] == 7]['user_clean'].fillna('').astype(str).tolist()
print(f"Number of documents in cluster: {len(cluster_texts)}")

# Print a sample of texts from the cluster
print("Sample texts:")
for i, text in enumerate(cluster_texts[:5]): # Print first 5 texts
    print(f"{i+1}. {text[:200]}...") # Print first 200 characters
# Out:
# --- Cluster 4 ---
# Number of documents in cluster: 246
# Sample texts:
# 1. explain the synchronizer token pattern in detail. describe the lifecycle of a stateful server-side anti-csrf token from generation to validation. what are the essential security properties this token ...
# 2. compare the double submit cookie pattern with the synchronizer token pattern. what are the primary advantages e.g. statelessness and disadvantages e.g. security weaknesses of the double submit cookie ...
# 3. imagine an application that allows changing a user s email address via a post request but requires the user s current password for confirmation. how does this design feature mitigate the risk of a sim...
# 4. explain how the saml security assertion markup language authentication protocol can be vulnerable to xxe. what is the potential impact of a successful xxe attack against a saml identity provider or se...
# 5. in a microservices architecture where data ownership and authorization logic might be distributed across multiple services what new challenges arise for preventing idor how can a central authorization...
#
# --- Cluster 5 ---
# Number of documents in cluster: 419
# Sample texts:
# 1. how do tools like sqlmap automate the process of detecting and exploiting time-based blind sqli explain the underlying logic it uses to measure response times and account for network jitter....
# 2. how would you write a waf rule to detect or block xxe attacks what are the challenges in writing a rule that is effective without generating a high number of false positives...
# 3. design a multi-layered rate-limiting strategy for a public api. your strategy should consider limits based on ip address api key and specific user account to provide a fair and secure service....
# 4. in a microservices architecture what is inter-service communication why is securing traffic between services east-west traffic just as important as securing traffic from the public internet north-sout...
# 5. explain the algorithm confusion attack rs256 to hs256 in detail. your explanation must cover:...
#
# --- Cluster 6 ---
# Number of documents in cluster: 314
# Sample texts:
# 1. explain the fundamental difference between an error-based sqli and a union-based sqli. describe a scenario where one would be preferable over the other for data exfiltration....
# 2. what is a stacked query injection e.g. using explain why this technique is often one of the most powerful and also one of the most frequently blocked. describe what specific database configurations or...
# 3. how would you manually perform a union-based sqli when the number of columns in the original query is unknown detail the step-by-step process using order by and union select to first determine the col...
# 4. explain the concept of type juggling in the context of sqli. how can a vulnerability in a loosely typed language like php lead to a waf bypass or an exploitable condition in a where clause that compar...
# 5. what are inline comments -- or and block comments / / and how are they used differently to truncate or manipulate a sql query during an injection attack provide a query example for each....
#
# --- Cluster 7 ---
# Number of documents in cluster: 388
# Sample texts:
# 1. can zip or zlib wrappers zip:// compress.zlib:// be used to exploit an lfi describe a plausible scenario for example involving a .zip archive on the target server....
# 2. what is a template sandbox explain its purpose as a security mechanism. then describe a high-level approach an attacker might take to find weaknesses in the sandbox configuration or known bypasses to ...
# 3. what are the specific memory corruption vulnerabilities in tls libraries that enable mitm attackers to inject malicious code during the handshake process and how do you exploit heap spray techniques i...
# 4. what is the mathematical framework for designing covert channels that exploit speculative execution vulnerabilities in modern processors and how do you quantify the information leakage through branch ...
# 5. how would you construct a covert channel using gpu memory access patterns that exploits the unified memory architecture in modern heterogeneous computing systems while evading performance counter-base...

# %% [markdown]
# # Asign names

# %%
# Assign a label to each SBERT cluster based on the analysis of example texts and common themes
sbert_cluster_labels_map = {
    0: "Web App Vulns (XSS, SQLi, Incident Response)",
    1: "Auth, Authz, Access Control & Related Tech",
    2: "Reflected XSS Techniques & WAF Bypass",
    3: "SSTI & Deserialization Vulns",
    4: "SQL Injection & Stored XSS Techniques",
    5: "Post-Exploitation & Lateral Movement (Windows LOTL)",
    6: "Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)",
    7: "Network & Communication Security (TLS, Microservices)"
}

# Map the cluster IDs to the new labels
df['sbert_cluster_label'] = df['sbert_cluster'].map(sbert_cluster_labels_map)

print("DataFrame with SBERT Cluster Labels:")
display(df[['user_clean', 'sbert_cluster', 'sbert_cluster_label']].head())

print("\nDistribution of SBERT Cluster Labels:")
print(df['sbert_cluster_label'].value_counts())
# Out:
# DataFrame with SBERT Cluster Labels:
#                                           user_clean  sbert_cluster  \
# 0  explain the fundamental data flow of a reflect...              3
# 1  how does a reflected xss vulnerability in an a...              3
# 2  what is dom clobbering and how can it be used ...              3
# 3  explain the concept of filter evasion in the c...              3
# 4  how can character encoding e.g. utf-7 utf-16 c...              3
#
#             sbert_cluster_label
# 0  SSTI & Deserialization Vulns
# 1  SSTI & Deserialization Vulns
# 2  SSTI & Deserialization Vulns
# 3  SSTI & Deserialization Vulns
# 4  SSTI & Deserialization Vulns
# Distribution of SBERT Cluster Labels:
# sbert_cluster_label
# Post-Exploitation & Lateral Movement (Windows LOTL)      419
# Network & Communication Security (TLS, Microservices)    388
# Web App Vulns (XSS, SQLi, Incident Response)             375
# Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)    314
# Auth, Authz, Access Control & Related Tech               271
# Reflected XSS Techniques & WAF Bypass                    248
# SQL Injection & Stored XSS Techniques                    246
# SSTI & Deserialization Vulns                             147
# Name: count, dtype: int64

# %%
# !pip install keybert torch torch_geometric
# Out:
# Requirement already satisfied: keybert in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from keybert) (2.0.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.12/dist-packages (from keybert) (13.9.4)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.12/dist-packages (from keybert) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from keybert) (5.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.4.0->keybert) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.4.0->keybert) (2.19.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->keybert) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->keybert) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->keybert) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.57.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.3.8->keybert) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.6.2)

# %%
print(df.columns)
# Out:
# Index(['system', 'user', 'assistant', 'system_clean', 'user_clean',
#        'assistant_clean', 'assistant_nlp', 'tokens', 'embedding_sbert',
#        'sbert_cluster', 'sbert_cluster_label'],
#       dtype='object')

# %%
# 1. Créer les features (déjà fait)
# attack_features = ...

# 2. Créer le graphe
data = HeteroData()
data['attack'].x = attack_features
data['target'].x = torch.ones((1, 1))

# Arête : attack → target
edge_index = [[i, 0] for i in range(len(attack_labels))]
data['attack', 'attacks', 'target'].edge_index = torch.tensor(edge_index).t()

# 🔑 AJOUTER : auto-boucle pour 'attack'
num_attacks = attack_features.size(0)
data['attack', 'self', 'attack'].edge_index = torch.arange(num_attacks).repeat(2, 1)

# 3. Modèle
class GTNModel(torch.nn.Module):
    def __init__(self, metadata, hidden_dim=128, num_classes=None):
        super().__init__()
        self.conv = HGTConv(
            in_channels={'attack': attack_features.shape[1], 'target': 1},
            out_channels=hidden_dim,
            metadata=metadata
        )
        self.classifier = torch.nn.Linear(hidden_dim, num_classes)

    def forward(self, x_dict, edge_index_dict):
        x_dict = self.conv(x_dict, edge_index_dict)
        return self.classifier(x_dict['attack'])  # ✅ maintenant présent

# 4. Instancier
model = GTNModel(metadata=data.metadata(), num_classes=len(attack_labels))

# 5. Tester
with torch.no_grad():
    out = model(data.x_dict, data.edge_index_dict)
    print("✅ Output shape:", out.shape)
# Out:
# ✅ Output shape: torch.Size([8, 8])

# %%
import networkx as nx

G = nx.Graph()
G.add_node("assistant", color="lightblue")

counts = df['sbert_cluster_label'].value_counts()
for attack, count in counts.items():
    G.add_node(attack, size=count)
    G.add_edge(attack, "assistant", weight=count)

pos = nx.spring_layout(G, k=0.5)
nx.draw(G, pos, with_labels=True, node_size=[200 + G.nodes[n].get('size',1)*50 for n in G.nodes()])
plt.show()

# %%
# Labels : [0, 1, 2, ..., 7] pour 8 clusters
labels = torch.arange(len(attack_labels))  # shape: [8]

# %%
import numpy as np
import torch
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# --- ÉTAPE 1 : Préparer les embeddings moyens par cluster (robuste) ---
df_clean = df.dropna(subset=['sbert_cluster_label', 'embedding_sbert']).copy()

def to_tensor(emb):
    if isinstance(emb, torch.Tensor):
        return emb.float()
    elif isinstance(emb, np.ndarray):
        return torch.tensor(emb, dtype=torch.float)
    elif isinstance(emb, list):
        return torch.tensor(emb, dtype=torch.float)
    else:
        try:
            import ast
            return torch.tensor(ast.literal_eval(emb), dtype=torch.float)
        except:
            return None

df_clean['emb_tensor'] = df_clean['embedding_sbert'].apply(to_tensor)
df_clean = df_clean[df_clean['emb_tensor'].notnull()]

if df_clean.empty:
    raise ValueError("Aucun embedding valide trouvé.")

# Vérifier la dimension
D = df_clean['emb_tensor'].iloc[0].shape[0]
df_clean = df_clean[df_clean['emb_tensor'].apply(lambda x: x.shape[0] == D)]

# Moyenne par cluster
cluster_groups = df_clean.groupby('sbert_cluster_label')['emb_tensor']
attack_labels = []
mean_embeddings = []

for label, group in cluster_groups:
    mean_emb = torch.stack(list(group)).mean(dim=0).numpy()
    attack_labels.append(label)
    mean_embeddings.append(mean_emb)

mean_embeddings = np.array(mean_embeddings)

# --- ÉTAPE 2 : Créer le graphe avec similarité ---
if len(attack_labels) == 1:
    print(f"⚠️ Un seul type d'attaque : '{attack_labels[0]}' → pas de relations possibles.")
    G = nx.Graph()
    G.add_node(attack_labels[0])
else:
    sim_matrix = cosine_similarity(mean_embeddings)
    G = nx.Graph()

    # Ajouter les nœuds
    for label in attack_labels:
        G.add_node(label)

    # Ajouter les arêtes avec similarité (seuil = 0.5)
    threshold = 0.5
    for i in range(len(attack_labels)):
        for j in range(i + 1, len(attack_labels)):
            sim = sim_matrix[i, j]
            if sim > threshold:
                # Arrondir à 2 décimales pour lisibilité
                G.add_edge(attack_labels[i], attack_labels[j], weight=sim, similarity=round(sim, 2))

# --- ÉTAPE 3 : Visualiser avec labels sur les arêtes ---
plt.figure(figsize=(14, 10))

if len(G.nodes) == 1:
    pos = {list(G.nodes)[0]: (0, 0)}
else:
    pos = nx.spring_layout(G, k=1.2, seed=42, iterations=50)

# Nœuds
nx.draw_networkx_nodes(G, pos, node_color='salmon', node_size=1200, alpha=0.9)
nx.draw_networkx_labels(G, pos, font_size=11, font_weight='bold', font_color='black')

# Arêtes
edge_weights = [G[u][v]['similarity'] * 2 for u, v in G.edges()]  # épaisseur proportionnelle
nx.draw_networkx_edges(G, pos, width=edge_weights, alpha=0.7, edge_color='gray')

# 🔑 AJOUT : Labels sur les arêtes
edge_labels = nx.get_edge_attributes(G, 'similarity')
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels=edge_labels,
    font_size=9,
    font_color='blue'
)

plt.title("Relations sémantiques entre types d'attaques\n(Les nombres sur les arêtes = similarité cosinus)", fontsize=13)
plt.axis('off')
plt.tight_layout()
plt.show()

# --- ÉTAPE 4 : Afficher les relations dans la console ---
if len(attack_labels) > 1:
    print("\n🔗 Relations avec similarité :\n")
    for u, v, data in G.edges(data=True):
        print(f"✅ '{u}' —— {data['similarity']} —— '{v}'")
else:
    print(f"\n⚠️ Un seul type d'attaque détecté : '{attack_labels[0]}'")
# Out:
# 🔗 Relations avec similarité :
#
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.5 —— 'Auth, Authz, Access Control & Related Tech'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.5299999713897705 —— 'Network & Communication Security (TLS, Microservices)'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.5600000023841858 —— 'Post-Exploitation & Lateral Movement (Windows LOTL)'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.6499999761581421 —— 'Reflected XSS Techniques & WAF Bypass'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.6600000262260437 —— 'SQL Injection & Stored XSS Techniques'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.699999988079071 —— 'SSTI & Deserialization Vulns'
# ✅ 'Advanced/Low-Level Attacks (Hardware, Rootkits, MITM)' —— 0.5899999737739563 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
# ✅ 'Auth, Authz, Access Control & Related Tech' —— 0.7200000286102295 —— 'Network & Communication Security (TLS, Microservices)'
# ✅ 'Auth, Authz, Access Control & Related Tech' —— 0.6899999976158142 —— 'Post-Exploitation & Lateral Movement (Windows LOTL)'
# ✅ 'Auth, Authz, Access Control & Related Tech' —— 0.7300000190734863 —— 'Reflected XSS Techniques & WAF Bypass'
# ✅ 'Auth, Authz, Access Control & Related Tech' —— 0.5699999928474426 —— 'SQL Injection & Stored XSS Techniques'
# ✅ 'Auth, Authz, Access Control & Related Tech' —— 0.7599999904632568 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
# ✅ 'Network & Communication Security (TLS, Microservices)' —— 0.6299999952316284 —— 'Post-Exploitation & Lateral Movement (Windows LOTL)'
# ✅ 'Network & Communication Security (TLS, Microservices)' —— 0.6000000238418579 —— 'Reflected XSS Techniques & WAF Bypass'
# ✅ 'Network & Communication Security (TLS, Microservices)' —— 0.8100000023841858 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
# ✅ 'Post-Exploitation & Lateral Movement (Windows LOTL)' —— 0.699999988079071 —— 'Reflected XSS Techniques & WAF Bypass'
# ✅ 'Post-Exploitation & Lateral Movement (Windows LOTL)' —— 0.6700000166893005 —— 'SQL Injection & Stored XSS Techniques'
# ✅ 'Post-Exploitation & Lateral Movement (Windows LOTL)' —— 0.6800000071525574 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
# ✅ 'Reflected XSS Techniques & WAF Bypass' —— 0.6299999952316284 —— 'SQL Injection & Stored XSS Techniques'
# ✅ 'Reflected XSS Techniques & WAF Bypass' —— 0.5 —— 'SSTI & Deserialization Vulns'
# ✅ 'Reflected XSS Techniques & WAF Bypass' —— 0.6899999976158142 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
# ✅ 'SQL Injection & Stored XSS Techniques' —— 0.6399999856948853 —— 'Web App Vulns (XSS, SQLi, Incident Response)'
